# %%
import numpy as np
import os
import json
import pandas as pd
import time
from tqdm import tqdm
import gc
import mmap
from scipy import spatial
import heapq
from sklearn.metrics import ndcg_score

# %%
# !pip install import-ipynb
import import_ipynb
# random.seed(0)

# %%
from src.show import show_playlist
from get_similar_tracks import SimilarTraks
from Rerank_docs import Rerank
from Vocab_class import TermVocab
from generate_vocab import create_vocab
collection_dir = '/media/harsh/Common/IITD/COL764-IR/Project/spotify_million_playlist_dataset/data/'
# Out:
# importing Jupyter notebook from get_similar_tracks.ipynb
# Creating Track Vocabulary
# Reading the dataset
# for file       : mpd.slice.102000-102999.json
# total playlists: 1000
# for file       : mpd.slice.103000-103999.json
# total playlists: 1000
# for file       : mpd.slice.104000-104999.json
# total playlists: 1000
# for file       : mpd.slice.101000-101999.json
# total playlists: 1000
# for file       : mpd.slice.10000-10999.json
# total playlists: 1000
# total time taken 0.8456723690032959
# 950
# importing Jupyter notebook from Rerank_docs.ipynb
# importing Jupyter notebook from create_co_occour_mat.ipynb
# Creating Track Vocabulary
# Creating Track Vocabulary

# %%
vocab, idf = create_vocab(collection_dir)
# Out:
# Creating Track Vocabulary

# %%
class Evaluate:
    def __init__(self, coll_dir, vocab, idf):
        self.coll_dir = coll_dir
        self.vocab = vocab
        self.idf = idf
        self.rerank = Rerank(self.coll_dir, TVocab= self.vocab, idf= self.idf, select_subset_of=20, apply_pca= True)
    
    def get_relevent_tracks(self, pid):
        actual_tracks = []
        playlist = show_playlist(self.coll_dir, pid, print_op=False)
        if playlist is None:
            return []
        for track in playlist['tracks']:
            actual_tracks.append(track['track_uri'])
        return actual_tracks[:500]
    
    def get_recommended_songs(self, pid):
        recommended = self.rerank.get_reranked_tracks(pid=pid)
        return recommended
    
    def r_precision(self, pid):
        recommended = self.get_recommended_songs(pid)
        relevent = self.get_relevent_tracks(pid)
        score = 0
        score = len(set(recommended) & set(relevent))
        score = score/len(relevent)
        #print('r_precision',score)
        return score
    
    def ndcg(self, recommended, relevent):
        score = 0
        #score = ndcg_score(relevent, recommended)
        if recommended[0] in relevent:
            score = 1
        index = 2
        idcg = 1
        for rec in recommended[1:]:
            rel_i = 1 if rec in relevent else 0
            score += rel_i/np.log2(index)
            idcg += 1/np.log2(index)
            index += 1
        score = score/idcg
        #print('ndcg', score)
        return score
        
    def click_at(self, pid):
        recommended = self.get_recommended_songs(pid)
        relevent = self.get_relevent_tracks(pid)
        #print('rec. tracks:',len(recommended))
        #print('rel. tracks:',len(relevent))
        click = 51
        for i,track in enumerate(recommended):
            if track in relevent:
                click = i/10
                break
        #print('click',click)
        return click
    
    def calc_metrices(self, pid):
        recommended = self.get_recommended_songs(pid)
        relevent = self.get_relevent_tracks(pid)
        print('pid        :',pid)
        print('rec. tracks:',len(recommended))
        print('rel. tracks:',len(relevent))
        click = 51
        for i,track in enumerate(recommended):
            if track in relevent:
                click = i/10
                break
        print('click      :',click)
        score = 0
        score = len(set(recommended) & set(relevent))
        score = score/len(relevent)
        print('r_precision:',score)
        ndcg_s = self.ndcg(recommended, relevent)
        print('ndcg       :',ndcg_s)
        return click, score, ndcg_s
    
    def avg_clicks(self, pids):
        avg_clicks = 0
        for pid in pids:
            avg_clicks += self.click_at(pid)
            #print(avg_clicks)
        avg_clicks /= len(pids)
        #print('avg Clicks:',avg_clicks)
        return avg_clicks
    
    def avg_metricess(self, pids):
        avg_clicks = 0
        avg_prec = 0
        avg_ndcg = 0
        for pid in pids:
            c, p, nd = self.calc_metrices(pid)
            avg_clicks += c
            avg_prec += p
            avg_ndcg += nd
            #print(avg_clicks)
        avg_clicks /= len(pids)
        avg_prec /= len(pids)
        avg_ndcg /= len(pids)
        print('avg Clicks   :',avg_clicks)
        print('avg Precision:',avg_prec)
        print('avg nDCG     :',avg_ndcg)
        return avg_clicks, avg_prec

# %%
evl = Evaluate(collection_dir, vocab=vocab, idf=idf)

# %%
evl.calc_metrices(324002)
# Out:
# Total similar playlists 100
# total tracks: 5238
# reccommended len (finally 500) 5238
# relevent tracks size: 165
# sampled relevent tracks 20
# pid        : 324002
# rec. tracks: 500
# rel. tracks: 165
# click      : 0.0
# r_precision: 0.12121212121212122
# ndcg       : 0.17079332977571976
# (0.0, 0.12121212121212122, 0.17079332977571976)

# %%
v_pids =[]
with open('validation_pids_1.txt','r') as f:
    v_pids = f.read().split()
    v_pids = [int(pid) for pid in v_pids]
evl.avg_metricess(v_pids[:])
# Out:
# Total similar playlists 100
# total tracks: 3396
# reccommended len (finally 500) 3396
# relevent tracks size: 44
# sampled relevent tracks 20
# pid        : 102000
# rec. tracks: 500
# rel. tracks: 44
# click      : 1.5
# r_precision: 0.22727272727272727
# ndcg       : 0.06112084280298722
# Total similar playlists 100
# total tracks: 3404
# reccommended len (finally 500) 3404
# relevent tracks size: 86
# sampled relevent tracks 20
# pid        : 102001
# rec. tracks: 500
# rel. tracks: 86
# click      : 4.0
# r_precision: 0.09302325581395349
# ndcg       : 0.11673490829789557
# Total similar playlists 100
# total tracks: 6239
# reccommended len (finally 500) 6239
# relevent tracks size: 39
# sampled relevent tracks 20
# pid        : 102002
# rec. tracks: 500
# rel. tracks: 39
# click      : 2.9
# r_precision: 0.07692307692307693
# ndcg       : 0.01854014361161559
# Total similar playlists 100
# total tracks: 2703
# reccommended len (finally 500) 2703
# relevent tracks size: 131
# sampled relevent tracks 20
# pid        : 102003
# rec. tracks: 500
# rel. tracks: 131
# click      : 0.8
# r_precision: 0.12213740458015267
# ndcg       : 0.06364260907286357
# Total similar playlists 100
# total tracks: 7728
# reccommended len (finally 500) 7728
# relevent tracks size: 62
# sampled relevent tracks 20
# pid        : 102004
# rec. tracks: 500
# rel. tracks: 62
# click      : 2.0
# r_precision: 0.08064516129032258
# ndcg       : 0.0696184107574592
# Total similar playlists 100
# total tracks: 1569
# reccommended len (finally 500) 1569
# relevent tracks size: 38
# sampled relevent tracks 20
# pid        : 102005
# rec. tracks: 500
# rel. tracks: 38
# click      : 2.3
# r_precision: 0.42105263157894735
# ndcg       : 0.07111503347853469
# Total similar playlists 100
# total tracks: 6187
# reccommended len (finally 500) 6187
# relevent tracks size: 104
# sampled relevent tracks 20
# pid        : 102006
# rec. tracks: 500
# rel. tracks: 104
# click      : 3.0
# r_precision: 0.08653846153846154
# ndcg       : 0.3833439811543226
# Total similar playlists 100
# total tracks: 3409
# reccommended len (finally 500) 3409
# relevent tracks size: 26
# sampled relevent tracks 20
# pid        : 102007
# rec. tracks: 500
# rel. tracks: 26
# click      : 4.4
# r_precision: 0.38461538461538464
# ndcg       : 0.07264461202087379
# Total similar playlists 100
# total tracks: 8683
# reccommended len (finally 500) 8683
# relevent tracks size: 55
# sampled relevent tracks 20
# pid        : 102008
# rec. tracks: 500
# rel. tracks: 55
# click      : 0.0
# r_precision: 0.01818181818181818
# ndcg       : 0.03682439211204289
# Total similar playlists 100
# total tracks: 5607
# reccommended len (finally 500) 5607
# relevent tracks size: 98
# sampled relevent tracks 20
# pid        : 102009
# rec. tracks: 500
# rel. tracks: 98
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 2826
# reccommended len (finally 500) 2826
# relevent tracks size: 43
# sampled relevent tracks 20
# pid        : 102010
# rec. tracks: 500
# rel. tracks: 43
# click      : 1.8
# r_precision: 0.3023255813953488
# ndcg       : 0.09875194004597766
# Total similar playlists 100
# total tracks: 4488
# reccommended len (finally 500) 4488
# relevent tracks size: 92
# sampled relevent tracks 20
# pid        : 102011
# rec. tracks: 500
# rel. tracks: 92
# click      : 1.9
# r_precision: 0.16304347826086957
# ndcg       : 0.10841330533190296
# Total similar playlists 100
# total tracks: 1644
# reccommended len (finally 500) 1644
# relevent tracks size: 176
# sampled relevent tracks 20
# pid        : 102012
# rec. tracks: 500
# rel. tracks: 176
# click      : 0.0
# r_precision: 0.375
# ndcg       : 0.2997174756329186
# Total similar playlists 100
# total tracks: 3253
# reccommended len (finally 500) 3253
# relevent tracks size: 52
# sampled relevent tracks 20
# pid        : 102013
# rec. tracks: 500
# rel. tracks: 52
# click      : 1.5
# r_precision: 0.46153846153846156
# ndcg       : 0.19078573728412884
# Total similar playlists 100
# total tracks: 10349
# reccommended len (finally 500) 10349
# relevent tracks size: 33
# sampled relevent tracks 20
# pid        : 102014
# rec. tracks: 500
# rel. tracks: 33
# click      : 5.0
# r_precision: 0.09090909090909091
# ndcg       : 0.01197859922102777
# Total similar playlists 100
# total tracks: 1511
# reccommended len (finally 500) 1511
# relevent tracks size: 59
# sampled relevent tracks 20
# pid        : 102015
# rec. tracks: 500
# rel. tracks: 59
# click      : 0.0
# r_precision: 0.2033898305084746
# ndcg       : 0.16284379955234204
# Total similar playlists 100
# total tracks: 2967
# reccommended len (finally 500) 2967
# relevent tracks size: 94
# sampled relevent tracks 20
# pid        : 102016
# rec. tracks: 500
# rel. tracks: 94
# click      : 1.4
# r_precision: 0.11702127659574468
# ndcg       : 0.05057341365897867
# Total similar playlists 100
# total tracks: 11691
# reccommended len (finally 500) 11691
# relevent tracks size: 36
# sampled relevent tracks 20
# pid        : 102018
# rec. tracks: 500
# rel. tracks: 36
# click      : 0.6
# r_precision: 0.5
# ndcg       : 0.12087394513079834
# Total similar playlists 100
# total tracks: 2375
# reccommended len (finally 500) 2375
# relevent tracks size: 52
# sampled relevent tracks 20
# pid        : 102019
# rec. tracks: 500
# rel. tracks: 52
# click      : 0.0
# r_precision: 0.34615384615384615
# ndcg       : 0.13188287530091308
# Total similar playlists 100
# total tracks: 3881
# reccommended len (finally 500) 3881
# relevent tracks size: 97
# sampled relevent tracks 20
# pid        : 102020
# rec. tracks: 500
# rel. tracks: 97
# click      : 0.5
# r_precision: 0.38144329896907214
# ndcg       : 0.19360467438943657
# Total similar playlists 100
# total tracks: 3914
# reccommended len (finally 500) 3914
# relevent tracks size: 17
# sampled relevent tracks 17
# pid        : 102021
# rec. tracks: 500
# rel. tracks: 17
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 8544
# reccommended len (finally 500) 8544
# relevent tracks size: 90
# sampled relevent tracks 20
# pid        : 102022
# rec. tracks: 500
# rel. tracks: 90
# click      : 41.6
# r_precision: 0.022222222222222223
# ndcg       : 0.0031753497445064396
# Total similar playlists 100
# total tracks: 1508
# reccommended len (finally 500) 1508
# relevent tracks size: 116
# sampled relevent tracks 20
# pid        : 102023
# rec. tracks: 500
# rel. tracks: 116
# click      : 0.0
# r_precision: 0.16379310344827586
# ndcg       : 0.10775555907730175
# Total similar playlists 100
# total tracks: 1822
# reccommended len (finally 500) 1822
# relevent tracks size: 62
# sampled relevent tracks 20
# pid        : 102024
# rec. tracks: 500
# rel. tracks: 62
# click      : 7.7
# r_precision: 0.016129032258064516
# ndcg       : 0.006409188698273483
# Total similar playlists 100
# total tracks: 5326
# reccommended len (finally 500) 5326
# relevent tracks size: 117
# sampled relevent tracks 20
# pid        : 102025
# rec. tracks: 500
# rel. tracks: 117
# click      : 0.0
# r_precision: 0.10256410256410256
# ndcg       : 0.1126422989698675
# Total similar playlists 100
# total tracks: 4406
# reccommended len (finally 500) 4406
# relevent tracks size: 85
# sampled relevent tracks 20
# pid        : 102026
# rec. tracks: 500
# rel. tracks: 85
# click      : 0.4
# r_precision: 0.023529411764705882
# ndcg       : 0.008289306964323166
# Total similar playlists 100
# total tracks: 3820
# reccommended len (finally 500) 3820
# relevent tracks size: 29
# sampled relevent tracks 20
# pid        : 102027
# rec. tracks: 500
# rel. tracks: 29
# click      : 0.0
# r_precision: 0.3793103448275862
# ndcg       : 0.11177858077691157
# Total similar playlists 100
# total tracks: 9159
# reccommended len (finally 500) 9159
# relevent tracks size: 192
# sampled relevent tracks 20
# pid        : 102028
# rec. tracks: 500
# rel. tracks: 192
# click      : 0.0
# r_precision: 0.06770833333333333
# ndcg       : 0.4092872093285509
# Total similar playlists 100
# total tracks: 2583
# reccommended len (finally 500) 2583
# relevent tracks size: 196
# sampled relevent tracks 20
# pid        : 102029
# rec. tracks: 500
# rel. tracks: 196
# click      : 0.0
# r_precision: 0.3010204081632653
# ndcg       : 0.3372892280966155
# Total similar playlists 100
# total tracks: 3758
# reccommended len (finally 500) 3758
# relevent tracks size: 142
# sampled relevent tracks 20
# pid        : 102030
# rec. tracks: 500
# rel. tracks: 142
# click      : 1.8
# r_precision: 0.11971830985915492
# ndcg       : 0.08208889617137015
# Total similar playlists 100
# total tracks: 1517
# reccommended len (finally 500) 1517
# relevent tracks size: 74
# sampled relevent tracks 20
# pid        : 102031
# rec. tracks: 500
# rel. tracks: 74
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 2864
# reccommended len (finally 500) 2864
# relevent tracks size: 19
# sampled relevent tracks 19
# pid        : 102032
# rec. tracks: 500
# rel. tracks: 19
# click      : 19.7
# r_precision: 0.10526315789473684
# ndcg       : 0.03597260415472994
# Total similar playlists 100
# total tracks: 9981
# reccommended len (finally 500) 9981
# relevent tracks size: 56
# sampled relevent tracks 20
# pid        : 102033
# rec. tracks: 500
# rel. tracks: 56
# click      : 2.1
# r_precision: 0.39285714285714285
# ndcg       : 0.15567084767974904
# Total similar playlists 100
# total tracks: 8682
# reccommended len (finally 500) 8682
# relevent tracks size: 63
# sampled relevent tracks 20
# pid        : 102034
# rec. tracks: 500
# rel. tracks: 63
# click      : 1.0
# r_precision: 0.06349206349206349
# ndcg       : 0.03505938644345364
# Total similar playlists 79
# total tracks: 10477
# reccommended len (finally 500) 10477
# relevent tracks size: 54
# sampled relevent tracks 20
# pid        : 102035
# rec. tracks: 500
# rel. tracks: 54
# click      : 2.9
# r_precision: 0.35185185185185186
# ndcg       : 0.040872218797755024
# Total similar playlists 86
# total tracks: 11436
# reccommended len (finally 500) 11436
# relevent tracks size: 24
# sampled relevent tracks 20
# pid        : 102036
# rec. tracks: 500
# rel. tracks: 24
# click      : 0.7
# r_precision: 0.5
# ndcg       : 0.04948093316347133
# Total similar playlists 100
# total tracks: 1903
# reccommended len (finally 500) 1903
# relevent tracks size: 15
# sampled relevent tracks 15
# pid        : 102037
# rec. tracks: 500
# rel. tracks: 15
# click      : 8.7
# r_precision: 0.26666666666666666
# ndcg       : 0.014595904203819005
# Total similar playlists 100
# total tracks: 1727
# reccommended len (finally 500) 1727
# relevent tracks size: 33
# sampled relevent tracks 20
# pid        : 102038
# rec. tracks: 500
# rel. tracks: 33
# click      : 2.2
# r_precision: 0.3333333333333333
# ndcg       : 0.074049428450316
# Total similar playlists 100
# total tracks: 9513
# reccommended len (finally 500) 9513
# relevent tracks size: 15
# sampled relevent tracks 15
# pid        : 102039
# rec. tracks: 500
# rel. tracks: 15
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 5765
# reccommended len (finally 500) 5765
# relevent tracks size: 47
# sampled relevent tracks 20
# pid        : 102040
# rec. tracks: 500
# rel. tracks: 47
# click      : 0.0
# r_precision: 0.19148936170212766
# ndcg       : 0.06784540976573097
# Total similar playlists 100
# total tracks: 5427
# reccommended len (finally 500) 5427
# relevent tracks size: 11
# sampled relevent tracks 11
# pid        : 102041
# rec. tracks: 500
# rel. tracks: 11
# click      : 1.1
# r_precision: 0.36363636363636365
# ndcg       : 0.037051818255272866
# Total similar playlists 100
# total tracks: 5366
# reccommended len (finally 500) 5366
# relevent tracks size: 115
# sampled relevent tracks 20
# pid        : 102042
# rec. tracks: 500
# rel. tracks: 115
# click      : 14.6
# r_precision: 0.043478260869565216
# ndcg       : 0.016891987047845877
# Total similar playlists 100
# total tracks: 3153
# reccommended len (finally 500) 3153
# relevent tracks size: 109
# sampled relevent tracks 20
# pid        : 102043
# rec. tracks: 500
# rel. tracks: 109
# click      : 0.0
# r_precision: 0.30275229357798167
# ndcg       : 0.22369655984062153
# Total similar playlists 100
# total tracks: 6016
# reccommended len (finally 500) 6016
# relevent tracks size: 29
# sampled relevent tracks 20
# pid        : 102044
# rec. tracks: 500
# rel. tracks: 29
# click      : 37.4
# r_precision: 0.034482758620689655
# ndcg       : 0.006432347518825373
# Total similar playlists 100
# total tracks: 6363
# reccommended len (finally 500) 6363
# relevent tracks size: 59
# sampled relevent tracks 20
# pid        : 102045
# rec. tracks: 500
# rel. tracks: 59
# click      : 23.4
# r_precision: 0.03389830508474576
# ndcg       : 0.005112778406333695
# Total similar playlists 100
# total tracks: 6358
# reccommended len (finally 500) 6358
# relevent tracks size: 64
# sampled relevent tracks 20
# pid        : 102046
# rec. tracks: 500
# rel. tracks: 64
# click      : 0.0
# r_precision: 0.375
# ndcg       : 0.2761803483024155
# Total similar playlists 100
# total tracks: 5582
# reccommended len (finally 500) 5582
# relevent tracks size: 18
# sampled relevent tracks 18
# pid        : 102047
# rec. tracks: 500
# rel. tracks: 18
# click      : 7.9
# r_precision: 0.2777777777777778
# ndcg       : 0.041777818881578464
# Total similar playlists 100
# total tracks: 2665
# reccommended len (finally 500) 2665
# relevent tracks size: 27
# sampled relevent tracks 20
# pid        : 102048
# rec. tracks: 500
# rel. tracks: 27
# click      : 25.0
# r_precision: 0.037037037037037035
# ndcg       : 0.0017558358441075081
# Total similar playlists 100
# total tracks: 1896
# reccommended len (finally 500) 1896
# relevent tracks size: 50
# sampled relevent tracks 20
# pid        : 102049
# rec. tracks: 500
# rel. tracks: 50
# click      : 0.4
# r_precision: 0.38
# ndcg       : 0.11856161948534268
# Total similar playlists 100
# total tracks: 2798
# reccommended len (finally 500) 2798
# relevent tracks size: 222
# sampled relevent tracks 20
# pid        : 102050
# rec. tracks: 500
# rel. tracks: 222
# click      : 0.0
# r_precision: 0.20270270270270271
# ndcg       : 0.1958237906202068
# Total similar playlists 100
# total tracks: 6585
# reccommended len (finally 500) 6585
# relevent tracks size: 116
# sampled relevent tracks 20
# pid        : 102051
# rec. tracks: 500
# rel. tracks: 116
# click      : 0.0
# r_precision: 0.5862068965517241
# ndcg       : 0.3218518142333873
# Total similar playlists 100
# total tracks: 4106
# reccommended len (finally 500) 4106
# relevent tracks size: 51
# sampled relevent tracks 20
# pid        : 102052
# rec. tracks: 500
# rel. tracks: 51
# click      : 1.8
# r_precision: 0.3333333333333333
# ndcg       : 0.18882980107602243
# Total similar playlists 100
# total tracks: 1351
# reccommended len (finally 500) 1351
# relevent tracks size: 15
# sampled relevent tracks 15
# pid        : 102053
# rec. tracks: 500
# rel. tracks: 15
# click      : 0.5
# r_precision: 0.2
# ndcg       : 0.015181442723639565
# Total similar playlists 100
# total tracks: 1953
# reccommended len (finally 500) 1953
# relevent tracks size: 70
# sampled relevent tracks 20
# pid        : 102054
# rec. tracks: 500
# rel. tracks: 70
# click      : 1.3
# r_precision: 0.21428571428571427
# ndcg       : 0.12668234965008665
# Total similar playlists 100
# total tracks: 9550
# reccommended len (finally 500) 9550
# relevent tracks size: 22
# sampled relevent tracks 20
# pid        : 102055
# rec. tracks: 500
# rel. tracks: 22
# click      : 18.4
# r_precision: 0.09090909090909091
# ndcg       : 0.005547831161836905
# Total similar playlists 100
# total tracks: 2192
# reccommended len (finally 500) 2192
# relevent tracks size: 46
# sampled relevent tracks 20
# pid        : 102056
# rec. tracks: 500
# rel. tracks: 46
# click      : 0.0
# r_precision: 0.3695652173913043
# ndcg       : 0.4286594089976903
# Total similar playlists 100
# total tracks: 6709
# reccommended len (finally 500) 6709
# relevent tracks size: 29
# sampled relevent tracks 20
# pid        : 102057
# rec. tracks: 500
# rel. tracks: 29
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 1824
# reccommended len (finally 500) 1824
# relevent tracks size: 29
# sampled relevent tracks 20
# pid        : 102058
# rec. tracks: 500
# rel. tracks: 29
# click      : 3.3
# r_precision: 0.4827586206896552
# ndcg       : 0.14363110797858808
# Total similar playlists 100
# total tracks: 5641
# reccommended len (finally 500) 5641
# relevent tracks size: 57
# sampled relevent tracks 20
# pid        : 102059
# rec. tracks: 500
# rel. tracks: 57
# click      : 5.2
# r_precision: 0.03508771929824561
# ndcg       : 0.006904183480290726
# Total similar playlists 100
# total tracks: 5113
# reccommended len (finally 500) 5113
# relevent tracks size: 30
# sampled relevent tracks 20
# pid        : 102060
# rec. tracks: 500
# rel. tracks: 30
# click      : 4.0
# r_precision: 0.16666666666666666
# ndcg       : 0.014727278421442705
# Total similar playlists 100
# total tracks: 2238
# reccommended len (finally 500) 2238
# relevent tracks size: 58
# sampled relevent tracks 20
# pid        : 102061
# rec. tracks: 500
# rel. tracks: 58
# click      : 1.0
# r_precision: 0.5
# ndcg       : 0.1643636799728883
# Total similar playlists 100
# total tracks: 4436
# reccommended len (finally 500) 4436
# relevent tracks size: 143
# sampled relevent tracks 20
# pid        : 102062
# rec. tracks: 500
# rel. tracks: 143
# click      : 0.0
# r_precision: 0.3076923076923077
# ndcg       : 0.2897435257050334
# Total similar playlists 100
# total tracks: 3960
# reccommended len (finally 500) 3960
# relevent tracks size: 38
# sampled relevent tracks 20
# pid        : 102063
# rec. tracks: 500
# rel. tracks: 38
# click      : 27.3
# r_precision: 0.10526315789473684
# ndcg       : 0.025029853988254865
# Total similar playlists 100
# total tracks: 3655
# reccommended len (finally 500) 3655
# relevent tracks size: 36
# sampled relevent tracks 20
# pid        : 102065
# rec. tracks: 500
# rel. tracks: 36
# click      : 14.2
# r_precision: 0.1388888888888889
# ndcg       : 0.039981348108021494
# Total similar playlists 100
# total tracks: 1615
# reccommended len (finally 500) 1615
# relevent tracks size: 110
# sampled relevent tracks 20
# pid        : 102066
# rec. tracks: 500
# rel. tracks: 110
# click      : 3.2
# r_precision: 0.2909090909090909
# ndcg       : 0.11561074922436322
# Total similar playlists 100
# total tracks: 2249
# reccommended len (finally 500) 2249
# relevent tracks size: 49
# sampled relevent tracks 20
# pid        : 102067
# rec. tracks: 500
# rel. tracks: 49
# click      : 0.0
# r_precision: 0.5102040816326531
# ndcg       : 0.16300975283899274
# Total similar playlists 100
# total tracks: 2421
# reccommended len (finally 500) 2421
# relevent tracks size: 190
# sampled relevent tracks 20
# pid        : 102068
# rec. tracks: 500
# rel. tracks: 190
# click      : 2.0
# r_precision: 0.08421052631578947
# ndcg       : 0.16615167339851963
# Total similar playlists 100
# total tracks: 5240
# reccommended len (finally 500) 5240
# relevent tracks size: 45
# sampled relevent tracks 20
# pid        : 102069
# rec. tracks: 500
# rel. tracks: 45
# click      : 0.4
# r_precision: 0.4888888888888889
# ndcg       : 0.16857374312329554
# Total similar playlists 100
# total tracks: 2386
# reccommended len (finally 500) 2386
# relevent tracks size: 66
# sampled relevent tracks 20
# pid        : 102070
# rec. tracks: 500
# rel. tracks: 66
# click      : 2.5
# r_precision: 0.22727272727272727
# ndcg       : 0.18220589475258495
# Total similar playlists 100
# total tracks: 11470
# reccommended len (finally 500) 11470
# relevent tracks size: 30
# sampled relevent tracks 20
# pid        : 102071
# rec. tracks: 500
# rel. tracks: 30
# click      : 0.0
# r_precision: 0.03333333333333333
# ndcg       : 0.1278147830464185
# Total similar playlists 100
# total tracks: 5486
# reccommended len (finally 500) 5486
# relevent tracks size: 126
# sampled relevent tracks 20
# pid        : 102072
# rec. tracks: 500
# rel. tracks: 126
# click      : 0.0
# r_precision: 0.10317460317460317
# ndcg       : 0.2904105045190191
# Total similar playlists 100
# total tracks: 8610
# reccommended len (finally 500) 8610
# relevent tracks size: 42
# sampled relevent tracks 20
# pid        : 102073
# rec. tracks: 500
# rel. tracks: 42
# click      : 0.9
# r_precision: 0.30952380952380953
# ndcg       : 0.0650532063495663
# Total similar playlists 100
# total tracks: 4886
# reccommended len (finally 500) 4886
# relevent tracks size: 66
# sampled relevent tracks 20
# pid        : 102074
# rec. tracks: 500
# rel. tracks: 66
# click      : 0.0
# r_precision: 0.10606060606060606
# ndcg       : 0.07848832022840242
# Total similar playlists 100
# total tracks: 1643
# reccommended len (finally 500) 1643
# relevent tracks size: 11
# sampled relevent tracks 11
# pid        : 102075
# rec. tracks: 500
# rel. tracks: 11
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 6158
# reccommended len (finally 500) 6158
# relevent tracks size: 75
# sampled relevent tracks 20
# pid        : 102076
# rec. tracks: 500
# rel. tracks: 75
# click      : 4.1
# r_precision: 0.05333333333333334
# ndcg       : 0.025309818444015572
# Total similar playlists 100
# total tracks: 1652
# reccommended len (finally 500) 1652
# relevent tracks size: 97
# sampled relevent tracks 20
# pid        : 102077
# rec. tracks: 500
# rel. tracks: 97
# click      : 1.6
# r_precision: 0.2268041237113402
# ndcg       : 0.09606744532794033
# Total similar playlists 100
# total tracks: 5572
# reccommended len (finally 500) 5572
# relevent tracks size: 104
# sampled relevent tracks 20
# pid        : 102078
# rec. tracks: 500
# rel. tracks: 104
# click      : 0.0
# r_precision: 0.15384615384615385
# ndcg       : 0.15113787135417758
# Total similar playlists 100
# total tracks: 1621
# reccommended len (finally 500) 1621
# relevent tracks size: 149
# sampled relevent tracks 20
# pid        : 102079
# rec. tracks: 500
# rel. tracks: 149
# click      : 0.0
# r_precision: 0.28187919463087246
# ndcg       : 0.322046525199696
# Total similar playlists 100
# total tracks: 1834
# reccommended len (finally 500) 1834
# relevent tracks size: 21
# sampled relevent tracks 20
# pid        : 102081
# rec. tracks: 500
# rel. tracks: 21
# click      : 0.3
# r_precision: 0.3333333333333333
# ndcg       : 0.03801890036795077
# Total similar playlists 100
# total tracks: 6966
# reccommended len (finally 500) 6966
# relevent tracks size: 22
# sampled relevent tracks 20
# pid        : 102082
# rec. tracks: 500
# rel. tracks: 22
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 1821
# reccommended len (finally 500) 1821
# relevent tracks size: 60
# sampled relevent tracks 20
# pid        : 102083
# rec. tracks: 500
# rel. tracks: 60
# click      : 0.2
# r_precision: 0.15
# ndcg       : 0.03223623339942918
# Total similar playlists 100
# total tracks: 5802
# reccommended len (finally 500) 5802
# relevent tracks size: 73
# sampled relevent tracks 20
# pid        : 102084
# rec. tracks: 500
# rel. tracks: 73
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 1664
# reccommended len (finally 500) 1664
# relevent tracks size: 20
# sampled relevent tracks 20
# pid        : 102085
# rec. tracks: 500
# rel. tracks: 20
# click      : 0.0
# r_precision: 0.65
# ndcg       : 0.13367480963111344
# Total similar playlists 100
# total tracks: 8957
# reccommended len (finally 500) 8957
# relevent tracks size: 43
# sampled relevent tracks 20
# pid        : 102087
# rec. tracks: 500
# rel. tracks: 43
# click      : 7.0
# r_precision: 0.09302325581395349
# ndcg       : 0.04909543966933535
# Total similar playlists 100
# total tracks: 1484
# reccommended len (finally 500) 1484
# relevent tracks size: 34
# sampled relevent tracks 20
# pid        : 102088
# rec. tracks: 500
# rel. tracks: 34
# click      : 0.0
# r_precision: 0.6176470588235294
# ndcg       : 0.3599728505617552
# Total similar playlists 100
# total tracks: 3931
# reccommended len (finally 500) 3931
# relevent tracks size: 36
# sampled relevent tracks 20
# pid        : 102089
# rec. tracks: 500
# rel. tracks: 36
# click      : 12.5
# r_precision: 0.1111111111111111
# ndcg       : 0.023488674825141803
# Total similar playlists 100
# total tracks: 1616
# reccommended len (finally 500) 1616
# relevent tracks size: 82
# sampled relevent tracks 20
# pid        : 102090
# rec. tracks: 500
# rel. tracks: 82
# click      : 1.2
# r_precision: 0.13414634146341464
# ndcg       : 0.04518846611029108
# Total similar playlists 100
# total tracks: 2069
# reccommended len (finally 500) 2069
# relevent tracks size: 176
# sampled relevent tracks 20
# pid        : 102091
# rec. tracks: 500
# rel. tracks: 176
# click      : 0.0
# r_precision: 0.3181818181818182
# ndcg       : 0.23175536871557115
# Total similar playlists 100
# total tracks: 1562
# reccommended len (finally 500) 1562
# relevent tracks size: 16
# sampled relevent tracks 16
# pid        : 102092
# rec. tracks: 500
# rel. tracks: 16
# click      : 0.2
# r_precision: 0.25
# ndcg       : 0.023098624443534808
# Total similar playlists 100
# total tracks: 4518
# reccommended len (finally 500) 4518
# relevent tracks size: 81
# sampled relevent tracks 20
# pid        : 102093
# rec. tracks: 500
# rel. tracks: 81
# click      : 0.1
# r_precision: 0.14814814814814814
# ndcg       : 0.07440540077917034
# Total similar playlists 100
# total tracks: 7772
# reccommended len (finally 500) 7772
# relevent tracks size: 165
# sampled relevent tracks 20
# pid        : 102094
# rec. tracks: 500
# rel. tracks: 165
# click      : 0.0
# r_precision: 0.3333333333333333
# ndcg       : 0.3649447288224071
# Total similar playlists 100
# total tracks: 5787
# reccommended len (finally 500) 5787
# relevent tracks size: 30
# sampled relevent tracks 20
# pid        : 102095
# rec. tracks: 500
# rel. tracks: 30
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 1613
# reccommended len (finally 500) 1613
# relevent tracks size: 93
# sampled relevent tracks 20
# pid        : 102096
# rec. tracks: 500
# rel. tracks: 93
# click      : 1.8
# r_precision: 0.3333333333333333
# ndcg       : 0.20757922930425043
# Total similar playlists 100
# total tracks: 1580
# reccommended len (finally 500) 1580
# relevent tracks size: 35
# sampled relevent tracks 20
# pid        : 102097
# rec. tracks: 500
# rel. tracks: 35
# click      : 6.1
# r_precision: 0.37142857142857144
# ndcg       : 0.06293424303648387
# Total similar playlists 100
# total tracks: 5276
# reccommended len (finally 500) 5276
# relevent tracks size: 37
# sampled relevent tracks 20
# pid        : 102098
# rec. tracks: 500
# rel. tracks: 37
# click      : 1.0
# r_precision: 0.13513513513513514
# ndcg       : 0.01910863932360383
# Total similar playlists 100
# total tracks: 9687
# reccommended len (finally 500) 9687
# relevent tracks size: 106
# sampled relevent tracks 20
# pid        : 102099
# rec. tracks: 500
# rel. tracks: 106
# click      : 1.0
# r_precision: 0.22641509433962265
# ndcg       : 0.13933418734185812
# Total similar playlists 100
# total tracks: 1694
# reccommended len (finally 500) 1694
# relevent tracks size: 42
# sampled relevent tracks 20
# pid        : 102100
# rec. tracks: 500
# rel. tracks: 42
# click      : 9.8
# r_precision: 0.23809523809523808
# ndcg       : 0.027953379106638924
# Total similar playlists 100
# total tracks: 9577
# reccommended len (finally 500) 9577
# relevent tracks size: 49
# sampled relevent tracks 20
# pid        : 102101
# rec. tracks: 500
# rel. tracks: 49
# click      : 2.1
# r_precision: 0.12244897959183673
# ndcg       : 0.04091175744084402
# Total similar playlists 100
# total tracks: 2555
# reccommended len (finally 500) 2555
# relevent tracks size: 83
# sampled relevent tracks 20
# pid        : 102102
# rec. tracks: 500
# rel. tracks: 83
# click      : 0.1
# r_precision: 0.25301204819277107
# ndcg       : 0.1572354487094501
# Total similar playlists 100
# total tracks: 2158
# reccommended len (finally 500) 2158
# relevent tracks size: 53
# sampled relevent tracks 20
# pid        : 102103
# rec. tracks: 500
# rel. tracks: 53
# click      : 2.1
# r_precision: 0.1509433962264151
# ndcg       : 0.023554317451359868
# Total similar playlists 100
# total tracks: 4760
# reccommended len (finally 500) 4760
# relevent tracks size: 55
# sampled relevent tracks 20
# pid        : 102104
# rec. tracks: 500
# rel. tracks: 55
# click      : 14.3
# r_precision: 0.03636363636363636
# ndcg       : 0.003653082816225035
# Total similar playlists 100
# total tracks: 10944
# reccommended len (finally 500) 10944
# relevent tracks size: 156
# sampled relevent tracks 20
# pid        : 102105
# rec. tracks: 500
# rel. tracks: 156
# click      : 1.5
# r_precision: 0.07051282051282051
# ndcg       : 0.03229080319035157
# Total similar playlists 100
# total tracks: 2418
# reccommended len (finally 500) 2418
# relevent tracks size: 248
# sampled relevent tracks 20
# pid        : 102106
# rec. tracks: 500
# rel. tracks: 248
# click      : 0.2
# r_precision: 0.13306451612903225
# ndcg       : 0.1269887678542566
# Total similar playlists 100
# total tracks: 7876
# reccommended len (finally 500) 7876
# relevent tracks size: 64
# sampled relevent tracks 20
# pid        : 102107
# rec. tracks: 500
# rel. tracks: 64
# click      : 0.0
# r_precision: 0.328125
# ndcg       : 0.16214330091833498
# Total similar playlists 100
# total tracks: 1460
# reccommended len (finally 500) 1460
# relevent tracks size: 38
# sampled relevent tracks 20
# pid        : 102108
# rec. tracks: 500
# rel. tracks: 38
# click      : 0.0
# r_precision: 0.6052631578947368
# ndcg       : 0.3359276221352682
# Total similar playlists 100
# total tracks: 7214
# reccommended len (finally 500) 7214
# relevent tracks size: 36
# sampled relevent tracks 20
# pid        : 102109
# rec. tracks: 500
# rel. tracks: 36
# click      : 1.3
# r_precision: 0.3611111111111111
# ndcg       : 0.1258693406246831
# Total similar playlists 100
# total tracks: 2909
# reccommended len (finally 500) 2909
# relevent tracks size: 44
# sampled relevent tracks 20
# pid        : 102110
# rec. tracks: 500
# rel. tracks: 44
# click      : 2.1
# r_precision: 0.09090909090909091
# ndcg       : 0.029970777068727
# Total similar playlists 100
# total tracks: 4923
# reccommended len (finally 500) 4923
# relevent tracks size: 65
# sampled relevent tracks 20
# pid        : 102111
# rec. tracks: 500
# rel. tracks: 65
# click      : 0.0
# r_precision: 0.12307692307692308
# ndcg       : 0.06102665716688199
# Total similar playlists 100
# total tracks: 3382
# reccommended len (finally 500) 3382
# relevent tracks size: 45
# sampled relevent tracks 20
# pid        : 102112
# rec. tracks: 500
# rel. tracks: 45
# click      : 7.7
# r_precision: 0.022222222222222223
# ndcg       : 0.0022268617691461813
# Total similar playlists 100
# total tracks: 6293
# reccommended len (finally 500) 6293
# relevent tracks size: 176
# sampled relevent tracks 20
# pid        : 102113
# rec. tracks: 500
# rel. tracks: 176
# click      : 1.1
# r_precision: 0.09090909090909091
# ndcg       : 0.18698828090592554
# Total similar playlists 100
# total tracks: 2932
# reccommended len (finally 500) 2932
# relevent tracks size: 96
# sampled relevent tracks 20
# pid        : 102114
# rec. tracks: 500
# rel. tracks: 96
# click      : 1.0
# r_precision: 0.010416666666666666
# ndcg       : 0.0040459599864570706
# Total similar playlists 100
# total tracks: 1539
# reccommended len (finally 500) 1539
# relevent tracks size: 30
# sampled relevent tracks 20
# pid        : 102115
# rec. tracks: 500
# rel. tracks: 30
# click      : 0.0
# r_precision: 0.43333333333333335
# ndcg       : 0.1940754149244598
# Total similar playlists 100
# total tracks: 8629
# reccommended len (finally 500) 8629
# relevent tracks size: 20
# sampled relevent tracks 20
# pid        : 102116
# rec. tracks: 500
# rel. tracks: 20
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 4287
# reccommended len (finally 500) 4287
# relevent tracks size: 105
# sampled relevent tracks 20
# pid        : 102117
# rec. tracks: 500
# rel. tracks: 105
# click      : 0.9
# r_precision: 0.1523809523809524
# ndcg       : 0.22707815851732835
# Total similar playlists 100
# total tracks: 3339
# reccommended len (finally 500) 3339
# relevent tracks size: 89
# sampled relevent tracks 20
# pid        : 102118
# rec. tracks: 500
# rel. tracks: 89
# click      : 2.9
# r_precision: 0.11235955056179775
# ndcg       : 0.22823934841066315
# Total similar playlists 100
# total tracks: 3356
# reccommended len (finally 500) 3356
# relevent tracks size: 76
# sampled relevent tracks 20
# pid        : 102119
# rec. tracks: 500
# rel. tracks: 76
# click      : 1.7
# r_precision: 0.09210526315789473
# ndcg       : 0.022195179811710024
# Total similar playlists 100
# total tracks: 4393
# reccommended len (finally 500) 4393
# relevent tracks size: 92
# sampled relevent tracks 20
# pid        : 102120
# rec. tracks: 500
# rel. tracks: 92
# click      : 0.0
# r_precision: 0.14130434782608695
# ndcg       : 0.133009595517977
# Total similar playlists 100
# total tracks: 1502
# reccommended len (finally 500) 1502
# relevent tracks size: 123
# sampled relevent tracks 20
# pid        : 102121
# rec. tracks: 500
# rel. tracks: 123
# click      : 0.0
# r_precision: 0.35772357723577236
# ndcg       : 0.3072711515091006
# Total similar playlists 100
# total tracks: 3918
# reccommended len (finally 500) 3918
# relevent tracks size: 38
# sampled relevent tracks 20
# pid        : 102122
# rec. tracks: 500
# rel. tracks: 38
# click      : 0.6
# r_precision: 0.10526315789473684
# ndcg       : 0.025099524660036218
# Total similar playlists 100
# total tracks: 2687
# reccommended len (finally 500) 2687
# relevent tracks size: 35
# sampled relevent tracks 20
# pid        : 102123
# rec. tracks: 500
# rel. tracks: 35
# click      : 0.0
# r_precision: 0.45714285714285713
# ndcg       : 0.05987115685208006
# Total similar playlists 100
# total tracks: 3837
# reccommended len (finally 500) 3837
# relevent tracks size: 61
# sampled relevent tracks 20
# pid        : 102124
# rec. tracks: 500
# rel. tracks: 61
# click      : 0.0
# r_precision: 0.29508196721311475
# ndcg       : 0.3237585911453132
# Total similar playlists 100
# total tracks: 3877
# reccommended len (finally 500) 3877
# relevent tracks size: 93
# sampled relevent tracks 20
# pid        : 102125
# rec. tracks: 500
# rel. tracks: 93
# click      : 4.6
# r_precision: 0.08602150537634409
# ndcg       : 0.045196230273843
# Total similar playlists 100
# total tracks: 2361
# reccommended len (finally 500) 2361
# relevent tracks size: 179
# sampled relevent tracks 20
# pid        : 102126
# rec. tracks: 500
# rel. tracks: 179
# click      : 0.0
# r_precision: 0.16759776536312848
# ndcg       : 0.12688011707493912
# Total similar playlists 100
# total tracks: 4873
# reccommended len (finally 500) 4873
# relevent tracks size: 13
# sampled relevent tracks 13
# pid        : 102127
# rec. tracks: 500
# rel. tracks: 13
# click      : 1.4
# r_precision: 0.07692307692307693
# ndcg       : 0.0035825732925881585
# Total similar playlists 100
# total tracks: 3613
# reccommended len (finally 500) 3613
# relevent tracks size: 119
# sampled relevent tracks 20
# pid        : 102128
# rec. tracks: 500
# rel. tracks: 119
# click      : 8.9
# r_precision: 0.07563025210084033
# ndcg       : 0.041690524461431
# Total similar playlists 100
# total tracks: 2280
# reccommended len (finally 500) 2280
# relevent tracks size: 30
# sampled relevent tracks 20
# pid        : 102129
# rec. tracks: 500
# rel. tracks: 30
# click      : 15.1
# r_precision: 0.26666666666666666
# ndcg       : 0.04899568289003648
# Total similar playlists 100
# total tracks: 3997
# reccommended len (finally 500) 3997
# relevent tracks size: 61
# sampled relevent tracks 20
# pid        : 102130
# rec. tracks: 500
# rel. tracks: 61
# click      : 4.2
# r_precision: 0.2459016393442623
# ndcg       : 0.13829936954289324
# Total similar playlists 100
# total tracks: 7786
# reccommended len (finally 500) 7786
# relevent tracks size: 40
# sampled relevent tracks 20
# pid        : 102131
# rec. tracks: 500
# rel. tracks: 40
# click      : 2.0
# r_precision: 0.1
# ndcg       : 0.03299411167517057
# Total similar playlists 100
# total tracks: 1804
# reccommended len (finally 500) 1804
# relevent tracks size: 17
# sampled relevent tracks 17
# pid        : 102132
# rec. tracks: 500
# rel. tracks: 17
# click      : 0.0
# r_precision: 0.47058823529411764
# ndcg       : 0.11799167419383398
# Total similar playlists 100
# total tracks: 2505
# reccommended len (finally 500) 2505
# relevent tracks size: 23
# sampled relevent tracks 20
# pid        : 102133
# rec. tracks: 500
# rel. tracks: 23
# click      : 3.3
# r_precision: 0.30434782608695654
# ndcg       : 0.0534968990446553
# Total similar playlists 100
# total tracks: 2761
# reccommended len (finally 500) 2761
# relevent tracks size: 105
# sampled relevent tracks 20
# pid        : 102134
# rec. tracks: 500
# rel. tracks: 105
# click      : 0.0
# r_precision: 0.3904761904761905
# ndcg       : 0.3259598859498994
# Total similar playlists 100
# total tracks: 4488
# reccommended len (finally 500) 4488
# relevent tracks size: 189
# sampled relevent tracks 20
# pid        : 102135
# rec. tracks: 500
# rel. tracks: 189
# click      : 0.0
# r_precision: 0.19047619047619047
# ndcg       : 0.23123747456043944
# Total similar playlists 100
# total tracks: 6728
# reccommended len (finally 500) 6728
# relevent tracks size: 50
# sampled relevent tracks 20
# pid        : 102136
# rec. tracks: 500
# rel. tracks: 50
# click      : 12.2
# r_precision: 0.04
# ndcg       : 0.003757208157592349
# Total similar playlists 100
# total tracks: 7540
# reccommended len (finally 500) 7540
# relevent tracks size: 71
# sampled relevent tracks 20
# pid        : 102137
# rec. tracks: 500
# rel. tracks: 71
# click      : 8.8
# r_precision: 0.11267605633802817
# ndcg       : 0.14670965856196694
# Total similar playlists 100
# total tracks: 5284
# reccommended len (finally 500) 5284
# relevent tracks size: 53
# sampled relevent tracks 20
# pid        : 102138
# rec. tracks: 500
# rel. tracks: 53
# click      : 1.0
# r_precision: 0.3018867924528302
# ndcg       : 0.12885771454755618
# Total similar playlists 100
# total tracks: 7471
# reccommended len (finally 500) 7471
# relevent tracks size: 50
# sampled relevent tracks 20
# pid        : 102140
# rec. tracks: 500
# rel. tracks: 50
# click      : 0.0
# r_precision: 0.3
# ndcg       : 0.17721020648936858
# Total similar playlists 100
# total tracks: 4199
# reccommended len (finally 500) 4199
# relevent tracks size: 22
# sampled relevent tracks 20
# pid        : 102141
# rec. tracks: 500
# rel. tracks: 22
# click      : 0.5
# r_precision: 0.3181818181818182
# ndcg       : 0.03174548210716555
# Total similar playlists 100
# total tracks: 4726
# reccommended len (finally 500) 4726
# relevent tracks size: 25
# sampled relevent tracks 20
# pid        : 102142
# rec. tracks: 500
# rel. tracks: 25
# click      : 4.5
# r_precision: 0.08
# ndcg       : 0.004414538707420293
# Total similar playlists 100
# total tracks: 1515
# reccommended len (finally 500) 1515
# relevent tracks size: 28
# sampled relevent tracks 20
# pid        : 102143
# rec. tracks: 500
# rel. tracks: 28
# click      : 1.1
# r_precision: 0.6785714285714286
# ndcg       : 0.18370120405490986
# Total similar playlists 100
# total tracks: 4889
# reccommended len (finally 500) 4889
# relevent tracks size: 31
# sampled relevent tracks 20
# pid        : 102144
# rec. tracks: 500
# rel. tracks: 31
# click      : 0.4
# r_precision: 0.22580645161290322
# ndcg       : 0.06510384666366434
# Total similar playlists 100
# total tracks: 1754
# reccommended len (finally 500) 1754
# relevent tracks size: 39
# sampled relevent tracks 20
# pid        : 102145
# rec. tracks: 500
# rel. tracks: 39
# click      : 0.1
# r_precision: 0.1282051282051282
# ndcg       : 0.03749855691922251
# Total similar playlists 100
# total tracks: 3306
# reccommended len (finally 500) 3306
# relevent tracks size: 65
# sampled relevent tracks 20
# pid        : 102146
# rec. tracks: 500
# rel. tracks: 65
# click      : 10.2
# r_precision: 0.06153846153846154
# ndcg       : 0.016329567863077137
# Total similar playlists 100
# total tracks: 4328
# reccommended len (finally 500) 4328
# relevent tracks size: 153
# sampled relevent tracks 20
# pid        : 102147
# rec. tracks: 500
# rel. tracks: 153
# click      : 6.4
# r_precision: 0.0392156862745098
# ndcg       : 0.02732882969746325
# Total similar playlists 100
# total tracks: 9429
# reccommended len (finally 500) 9429
# relevent tracks size: 109
# sampled relevent tracks 20
# pid        : 102148
# rec. tracks: 500
# rel. tracks: 109
# click      : 4.4
# r_precision: 0.03669724770642202
# ndcg       : 0.014925072243517327
# Total similar playlists 100
# total tracks: 4258
# reccommended len (finally 500) 4258
# relevent tracks size: 84
# sampled relevent tracks 20
# pid        : 102149
# rec. tracks: 500
# rel. tracks: 84
# click      : 0.0
# r_precision: 0.047619047619047616
# ndcg       : 0.035373653013991584
# Total similar playlists 100
# total tracks: 9113
# reccommended len (finally 500) 9113
# relevent tracks size: 181
# sampled relevent tracks 20
# pid        : 102150
# rec. tracks: 500
# rel. tracks: 181
# click      : 0.0
# r_precision: 0.10497237569060773
# ndcg       : 0.12162458977218454
# Total similar playlists 100
# total tracks: 1779
# reccommended len (finally 500) 1779
# relevent tracks size: 32
# sampled relevent tracks 20
# pid        : 102151
# rec. tracks: 500
# rel. tracks: 32
# click      : 0.0
# r_precision: 0.25
# ndcg       : 0.10775587527439127
# Total similar playlists 100
# total tracks: 4436
# reccommended len (finally 500) 4436
# relevent tracks size: 38
# sampled relevent tracks 20
# pid        : 102152
# rec. tracks: 500
# rel. tracks: 38
# click      : 0.0
# r_precision: 0.23684210526315788
# ndcg       : 0.11859990937025028
# Total similar playlists 100
# total tracks: 8476
# reccommended len (finally 500) 8476
# relevent tracks size: 141
# sampled relevent tracks 20
# pid        : 102153
# rec. tracks: 500
# rel. tracks: 141
# click      : 3.1
# r_precision: 0.014184397163120567
# ndcg       : 0.005032821110080063
# Total similar playlists 100
# total tracks: 4128
# reccommended len (finally 500) 4128
# relevent tracks size: 55
# sampled relevent tracks 20
# pid        : 102154
# rec. tracks: 500
# rel. tracks: 55
# click      : 2.8
# r_precision: 0.07272727272727272
# ndcg       : 0.013644341232538295
# Total similar playlists 100
# total tracks: 3413
# reccommended len (finally 500) 3413
# relevent tracks size: 20
# sampled relevent tracks 20
# pid        : 102155
# rec. tracks: 500
# rel. tracks: 20
# click      : 3.0
# r_precision: 0.15
# ndcg       : 0.010407293307953116
# Total similar playlists 100
# total tracks: 7606
# reccommended len (finally 500) 7606
# relevent tracks size: 38
# sampled relevent tracks 20
# pid        : 102156
# rec. tracks: 500
# rel. tracks: 38
# click      : 3.1
# r_precision: 0.2894736842105263
# ndcg       : 0.09948502959055439
# Total similar playlists 100
# total tracks: 2959
# reccommended len (finally 500) 2959
# relevent tracks size: 80
# sampled relevent tracks 20
# pid        : 102157
# rec. tracks: 500
# rel. tracks: 80
# click      : 0.0
# r_precision: 0.4
# ndcg       : 0.4131247782388271
# Total similar playlists 100
# total tracks: 1609
# reccommended len (finally 500) 1609
# relevent tracks size: 48
# sampled relevent tracks 20
# pid        : 102158
# rec. tracks: 500
# rel. tracks: 48
# click      : 0.5
# r_precision: 0.20833333333333334
# ndcg       : 0.045412461893417085
# Total similar playlists 100
# total tracks: 11018
# reccommended len (finally 500) 11018
# relevent tracks size: 105
# sampled relevent tracks 20
# pid        : 102160
# rec. tracks: 500
# rel. tracks: 105
# click      : 3.7
# r_precision: 0.08571428571428572
# ndcg       : 0.05123435585749413
# Total similar playlists 100
# total tracks: 2054
# reccommended len (finally 500) 2054
# relevent tracks size: 37
# sampled relevent tracks 20
# pid        : 102161
# rec. tracks: 500
# rel. tracks: 37
# click      : 10.0
# r_precision: 0.08108108108108109
# ndcg       : 0.007874496306417546
# Total similar playlists 100
# total tracks: 2433
# reccommended len (finally 500) 2433
# relevent tracks size: 195
# sampled relevent tracks 20
# pid        : 102162
# rec. tracks: 500
# rel. tracks: 195
# click      : 0.0
# r_precision: 0.26153846153846155
# ndcg       : 0.18915573392906287
# Total similar playlists 100
# total tracks: 1604
# reccommended len (finally 500) 1604
# relevent tracks size: 15
# sampled relevent tracks 15
# pid        : 102163
# rec. tracks: 500
# rel. tracks: 15
# click      : 14.2
# r_precision: 0.3333333333333333
# ndcg       : 0.03242844403080035
# Total similar playlists 100
# total tracks: 8839
# reccommended len (finally 500) 8839
# relevent tracks size: 50
# sampled relevent tracks 20
# pid        : 102164
# rec. tracks: 500
# rel. tracks: 50
# click      : 1.2
# r_precision: 0.18
# ndcg       : 0.07098361733530618
# Total similar playlists 29
# total tracks: 3800
# reccommended len (finally 500) 3800
# relevent tracks size: 38
# sampled relevent tracks 20
# pid        : 102165
# rec. tracks: 500
# rel. tracks: 38
# click      : 2.1
# r_precision: 0.34210526315789475
# ndcg       : 0.028165719003384788
# Total similar playlists 100
# total tracks: 9787
# reccommended len (finally 500) 9787
# relevent tracks size: 146
# sampled relevent tracks 20
# pid        : 102166
# rec. tracks: 500
# rel. tracks: 146
# click      : 47.9
# r_precision: 0.00684931506849315
# ndcg       : 0.001571448728896694
# Total similar playlists 100
# total tracks: 4650
# reccommended len (finally 500) 4650
# relevent tracks size: 131
# sampled relevent tracks 20
# pid        : 102167
# rec. tracks: 500
# rel. tracks: 131
# click      : 2.4
# r_precision: 0.06870229007633588
# ndcg       : 0.3107640490338062
# Total similar playlists 100
# total tracks: 2373
# reccommended len (finally 500) 2373
# relevent tracks size: 18
# sampled relevent tracks 18
# pid        : 102168
# rec. tracks: 500
# rel. tracks: 18
# click      : 13.0
# r_precision: 0.1111111111111111
# ndcg       : 0.019091049401076095
# Total similar playlists 100
# total tracks: 2165
# reccommended len (finally 500) 2165
# relevent tracks size: 162
# sampled relevent tracks 20
# pid        : 102169
# rec. tracks: 500
# rel. tracks: 162
# click      : 2.8
# r_precision: 0.12345679012345678
# ndcg       : 0.12534438871244657
# Total similar playlists 100
# total tracks: 1795
# reccommended len (finally 500) 1795
# relevent tracks size: 150
# sampled relevent tracks 20
# pid        : 102170
# rec. tracks: 500
# rel. tracks: 150
# click      : 7.2
# r_precision: 0.03333333333333333
# ndcg       : 0.027439294030311406
# Total similar playlists 100
# total tracks: 10350
# reccommended len (finally 500) 10350
# relevent tracks size: 23
# sampled relevent tracks 20
# pid        : 102171
# rec. tracks: 500
# rel. tracks: 23
# click      : 16.5
# r_precision: 0.21739130434782608
# ndcg       : 0.0648752492315901
# Total similar playlists 100
# total tracks: 2760
# reccommended len (finally 500) 2760
# relevent tracks size: 21
# sampled relevent tracks 20
# pid        : 102172
# rec. tracks: 500
# rel. tracks: 21
# click      : 5.6
# r_precision: 0.19047619047619047
# ndcg       : 0.03134555971804823
# Total similar playlists 100
# total tracks: 8555
# reccommended len (finally 500) 8555
# relevent tracks size: 160
# sampled relevent tracks 20
# pid        : 102173
# rec. tracks: 500
# rel. tracks: 160
# click      : 0.0
# r_precision: 0.10625
# ndcg       : 0.08600161270337243
# Total similar playlists 100
# total tracks: 7907
# reccommended len (finally 500) 7907
# relevent tracks size: 19
# sampled relevent tracks 19
# pid        : 102174
# rec. tracks: 500
# rel. tracks: 19
# click      : 0.6
# r_precision: 0.3157894736842105
# ndcg       : 0.028015346889936968
# Total similar playlists 100
# total tracks: 1558
# reccommended len (finally 500) 1558
# relevent tracks size: 75
# sampled relevent tracks 20
# pid        : 102175
# rec. tracks: 500
# rel. tracks: 75
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 6035
# reccommended len (finally 500) 6035
# relevent tracks size: 128
# sampled relevent tracks 20
# pid        : 102176
# rec. tracks: 500
# rel. tracks: 128
# click      : 0.4
# r_precision: 0.1796875
# ndcg       : 0.13161020488743894
# Total similar playlists 100
# total tracks: 2336
# reccommended len (finally 500) 2336
# relevent tracks size: 182
# sampled relevent tracks 20
# pid        : 102177
# rec. tracks: 500
# rel. tracks: 182
# click      : 1.5
# r_precision: 0.06043956043956044
# ndcg       : 0.04372858350881189
# Total similar playlists 100
# total tracks: 1863
# reccommended len (finally 500) 1863
# relevent tracks size: 46
# sampled relevent tracks 20
# pid        : 102178
# rec. tracks: 500
# rel. tracks: 46
# click      : 5.5
# r_precision: 0.06521739130434782
# ndcg       : 0.008144223878648592
# Total similar playlists 100
# total tracks: 6400
# reccommended len (finally 500) 6400
# relevent tracks size: 36
# sampled relevent tracks 20
# pid        : 102179
# rec. tracks: 500
# rel. tracks: 36
# click      : 6.8
# r_precision: 0.08333333333333333
# ndcg       : 0.027676888534134313
# Total similar playlists 100
# total tracks: 4154
# reccommended len (finally 500) 4154
# relevent tracks size: 16
# sampled relevent tracks 16
# pid        : 102180
# rec. tracks: 500
# rel. tracks: 16
# click      : 0.5
# r_precision: 0.125
# ndcg       : 0.022776405313215578
# Total similar playlists 100
# total tracks: 7009
# reccommended len (finally 500) 7009
# relevent tracks size: 41
# sampled relevent tracks 20
# pid        : 102181
# rec. tracks: 500
# rel. tracks: 41
# click      : 4.0
# r_precision: 0.024390243902439025
# ndcg       : 0.00514652477305835
# Total similar playlists 100
# total tracks: 5445
# reccommended len (finally 500) 5445
# relevent tracks size: 67
# sampled relevent tracks 20
# pid        : 102182
# rec. tracks: 500
# rel. tracks: 67
# click      : 0.0
# r_precision: 0.6716417910447762
# ndcg       : 0.39682972339574557
# Total similar playlists 100
# total tracks: 8645
# reccommended len (finally 500) 8645
# relevent tracks size: 174
# sampled relevent tracks 20
# pid        : 102183
# rec. tracks: 500
# rel. tracks: 174
# click      : 11.5
# r_precision: 0.034482758620689655
# ndcg       : 0.01091199034361171
# Total similar playlists 100
# total tracks: 3666
# reccommended len (finally 500) 3666
# relevent tracks size: 162
# sampled relevent tracks 20
# pid        : 102184
# rec. tracks: 500
# rel. tracks: 162
# click      : 1.3
# r_precision: 0.04938271604938271
# ndcg       : 0.06637862351036027
# Total similar playlists 100
# total tracks: 3017
# ...
# sampled relevent tracks 20
# pid        : 10139
# rec. tracks: 500
# rel. tracks: 63
# click      : 1.2
# r_precision: 0.015873015873015872
# ndcg       : 0.017964740166695168
# Total similar playlists 100
# total tracks: 3519
# reccommended len (finally 500) 3519
# relevent tracks size: 19
# sampled relevent tracks 19
# pid        : 10140
# rec. tracks: 500
# rel. tracks: 19
# click      : 1.8
# r_precision: 0.10526315789473684
# ndcg       : 0.00530099585860508
# Total similar playlists 100
# total tracks: 6210
# reccommended len (finally 500) 6210
# relevent tracks size: 11
# sampled relevent tracks 11
# pid        : 10141
# rec. tracks: 500
# rel. tracks: 11
# click      : 7.9
# r_precision: 0.45454545454545453
# ndcg       : 0.021377056340259347
# Total similar playlists 100
# total tracks: 5473
# reccommended len (finally 500) 5473
# relevent tracks size: 55
# sampled relevent tracks 20
# pid        : 10142
# rec. tracks: 500
# rel. tracks: 55
# click      : 2.4
# r_precision: 0.23636363636363636
# ndcg       : 0.03942596460634465
# Total similar playlists 100
# total tracks: 1605
# reccommended len (finally 500) 1605
# relevent tracks size: 13
# sampled relevent tracks 13
# pid        : 10144
# rec. tracks: 500
# rel. tracks: 13
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 10412
# reccommended len (finally 500) 10412
# relevent tracks size: 19
# sampled relevent tracks 19
# pid        : 10145
# rec. tracks: 500
# rel. tracks: 19
# click      : 0.3
# r_precision: 0.8421052631578947
# ndcg       : 0.0798389054351717
# Total similar playlists 100
# total tracks: 2101
# reccommended len (finally 500) 2101
# relevent tracks size: 15
# sampled relevent tracks 15
# pid        : 10146
# rec. tracks: 500
# rel. tracks: 15
# click      : 0.0
# r_precision: 0.26666666666666666
# ndcg       : 0.05448033546904951
# Total similar playlists 100
# total tracks: 3312
# reccommended len (finally 500) 3312
# relevent tracks size: 24
# sampled relevent tracks 20
# pid        : 10147
# rec. tracks: 500
# rel. tracks: 24
# click      : 0.1
# r_precision: 0.041666666666666664
# ndcg       : 0.05303897392300355
# Total similar playlists 100
# total tracks: 5133
# reccommended len (finally 500) 5133
# relevent tracks size: 150
# sampled relevent tracks 20
# pid        : 10148
# rec. tracks: 500
# rel. tracks: 150
# click      : 1.4
# r_precision: 0.28
# ndcg       : 0.2714544471276775
# Total similar playlists 100
# total tracks: 5446
# reccommended len (finally 500) 5446
# relevent tracks size: 76
# sampled relevent tracks 20
# pid        : 10149
# rec. tracks: 500
# rel. tracks: 76
# click      : 8.2
# r_precision: 0.09210526315789473
# ndcg       : 0.06527889965653974
# Total similar playlists 100
# total tracks: 3367
# reccommended len (finally 500) 3367
# relevent tracks size: 30
# sampled relevent tracks 20
# pid        : 10150
# rec. tracks: 500
# rel. tracks: 30
# click      : 18.0
# r_precision: 0.13333333333333333
# ndcg       : 0.09418918907406816
# Total similar playlists 100
# total tracks: 9183
# reccommended len (finally 500) 9183
# relevent tracks size: 212
# sampled relevent tracks 20
# pid        : 10151
# rec. tracks: 500
# rel. tracks: 212
# click      : 2.4
# r_precision: 0.05660377358490566
# ndcg       : 0.35355872043080255
# Total similar playlists 100
# total tracks: 4465
# reccommended len (finally 500) 4465
# relevent tracks size: 137
# sampled relevent tracks 20
# pid        : 10152
# rec. tracks: 500
# rel. tracks: 137
# click      : 3.6
# r_precision: 0.0948905109489051
# ndcg       : 0.0469522921070634
# Total similar playlists 100
# total tracks: 4073
# reccommended len (finally 500) 4073
# relevent tracks size: 64
# sampled relevent tracks 20
# pid        : 10153
# rec. tracks: 500
# rel. tracks: 64
# click      : 0.8
# r_precision: 0.078125
# ndcg       : 0.01623413197985949
# Total similar playlists 100
# total tracks: 4120
# reccommended len (finally 500) 4120
# relevent tracks size: 17
# sampled relevent tracks 17
# pid        : 10154
# rec. tracks: 500
# rel. tracks: 17
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 1674
# reccommended len (finally 500) 1674
# relevent tracks size: 60
# sampled relevent tracks 20
# pid        : 10155
# rec. tracks: 500
# rel. tracks: 60
# click      : 0.0
# r_precision: 0.13333333333333333
# ndcg       : 0.05189016103427018
# Total similar playlists 100
# total tracks: 1969
# reccommended len (finally 500) 1969
# relevent tracks size: 181
# sampled relevent tracks 20
# pid        : 10156
# rec. tracks: 500
# rel. tracks: 181
# click      : 0.7
# r_precision: 0.30939226519337015
# ndcg       : 0.20087024323300012
# Total similar playlists 100
# total tracks: 1397
# reccommended len (finally 500) 1397
# relevent tracks size: 17
# sampled relevent tracks 17
# pid        : 10157
# rec. tracks: 500
# rel. tracks: 17
# click      : 1.1
# r_precision: 0.23529411764705882
# ndcg       : 0.011394593959571476
# Total similar playlists 100
# total tracks: 6786
# reccommended len (finally 500) 6786
# relevent tracks size: 13
# sampled relevent tracks 13
# pid        : 10158
# rec. tracks: 500
# rel. tracks: 13
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 5109
# reccommended len (finally 500) 5109
# relevent tracks size: 89
# sampled relevent tracks 20
# pid        : 10159
# rec. tracks: 500
# rel. tracks: 89
# click      : 1.2
# r_precision: 0.0449438202247191
# ndcg       : 0.062118147438963725
# Total similar playlists 100
# total tracks: 9643
# reccommended len (finally 500) 9643
# relevent tracks size: 250
# sampled relevent tracks 20
# pid        : 10160
# rec. tracks: 500
# rel. tracks: 250
# click      : 0.0
# r_precision: 0.184
# ndcg       : 0.20867023208293492
# Total similar playlists 100
# total tracks: 6210
# reccommended len (finally 500) 6210
# relevent tracks size: 113
# sampled relevent tracks 20
# pid        : 10161
# rec. tracks: 500
# rel. tracks: 113
# click      : 0.0
# r_precision: 0.07079646017699115
# ndcg       : 0.08659194033501405
# Total similar playlists 100
# total tracks: 1380
# reccommended len (finally 500) 1380
# relevent tracks size: 134
# sampled relevent tracks 20
# pid        : 10162
# rec. tracks: 500
# rel. tracks: 134
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 3891
# reccommended len (finally 500) 3891
# relevent tracks size: 42
# sampled relevent tracks 20
# pid        : 10163
# rec. tracks: 500
# rel. tracks: 42
# click      : 0.0
# r_precision: 0.40476190476190477
# ndcg       : 0.11941311041204634
# Total similar playlists 100
# total tracks: 5455
# reccommended len (finally 500) 5455
# relevent tracks size: 93
# sampled relevent tracks 20
# pid        : 10164
# rec. tracks: 500
# rel. tracks: 93
# click      : 0.6
# r_precision: 0.0967741935483871
# ndcg       : 0.03791663363331969
# Total similar playlists 100
# total tracks: 1486
# reccommended len (finally 500) 1486
# relevent tracks size: 30
# sampled relevent tracks 20
# pid        : 10165
# rec. tracks: 500
# rel. tracks: 30
# click      : 7.6
# r_precision: 0.6666666666666666
# ndcg       : 0.11053491133848904
# Total similar playlists 100
# total tracks: 1433
# reccommended len (finally 500) 1433
# relevent tracks size: 114
# sampled relevent tracks 20
# pid        : 10166
# rec. tracks: 500
# rel. tracks: 114
# click      : 0.2
# r_precision: 0.05263157894736842
# ndcg       : 0.03203820112863425
# Total similar playlists 100
# total tracks: 1506
# reccommended len (finally 500) 1506
# relevent tracks size: 25
# sampled relevent tracks 20
# pid        : 10167
# rec. tracks: 500
# rel. tracks: 25
# click      : 0.5
# r_precision: 0.4
# ndcg       : 0.051202393127559004
# Total similar playlists 100
# total tracks: 1505
# reccommended len (finally 500) 1505
# relevent tracks size: 39
# sampled relevent tracks 20
# pid        : 10168
# rec. tracks: 500
# rel. tracks: 39
# click      : 6.7
# r_precision: 0.3333333333333333
# ndcg       : 0.09225009371841177
# Total similar playlists 100
# total tracks: 2230
# reccommended len (finally 500) 2230
# relevent tracks size: 23
# sampled relevent tracks 20
# pid        : 10169
# rec. tracks: 500
# rel. tracks: 23
# click      : 32.3
# r_precision: 0.08695652173913043
# ndcg       : 0.0065897182446106595
# Total similar playlists 100
# total tracks: 3510
# reccommended len (finally 500) 3510
# relevent tracks size: 132
# sampled relevent tracks 20
# pid        : 10170
# rec. tracks: 500
# rel. tracks: 132
# click      : 0.0
# r_precision: 0.17424242424242425
# ndcg       : 0.27728201736296365
# Total similar playlists 100
# total tracks: 9298
# reccommended len (finally 500) 9298
# relevent tracks size: 84
# sampled relevent tracks 20
# pid        : 10171
# rec. tracks: 500
# rel. tracks: 84
# click      : 3.1
# r_precision: 0.16666666666666666
# ndcg       : 0.10523629492904331
# Total similar playlists 100
# total tracks: 6470
# reccommended len (finally 500) 6470
# relevent tracks size: 152
# sampled relevent tracks 20
# pid        : 10172
# rec. tracks: 500
# rel. tracks: 152
# click      : 14.8
# r_precision: 0.02631578947368421
# ndcg       : 0.04615140417747027
# Total similar playlists 100
# total tracks: 1694
# reccommended len (finally 500) 1694
# relevent tracks size: 97
# sampled relevent tracks 20
# pid        : 10173
# rec. tracks: 500
# rel. tracks: 97
# click      : 0.9
# r_precision: 0.08247422680412371
# ndcg       : 0.032901434410818726
# Total similar playlists 100
# total tracks: 1517
# reccommended len (finally 500) 1517
# relevent tracks size: 15
# sampled relevent tracks 15
# pid        : 10174
# rec. tracks: 500
# rel. tracks: 15
# click      : 0.0
# r_precision: 0.06666666666666667
# ndcg       : 0.013996721904890921
# Total similar playlists 100
# total tracks: 7620
# reccommended len (finally 500) 7620
# relevent tracks size: 48
# sampled relevent tracks 20
# pid        : 10175
# rec. tracks: 500
# rel. tracks: 48
# click      : 4.0
# r_precision: 0.08333333333333333
# ndcg       : 0.03294547350862652
# Total similar playlists 100
# total tracks: 8610
# reccommended len (finally 500) 8610
# relevent tracks size: 40
# sampled relevent tracks 20
# pid        : 10176
# rec. tracks: 500
# rel. tracks: 40
# click      : 0.0
# r_precision: 0.45
# ndcg       : 0.09877358877849146
# Total similar playlists 100
# total tracks: 2898
# reccommended len (finally 500) 2898
# relevent tracks size: 86
# sampled relevent tracks 20
# pid        : 10177
# rec. tracks: 500
# rel. tracks: 86
# click      : 0.4
# r_precision: 0.09302325581395349
# ndcg       : 0.03396845640457151
# Total similar playlists 100
# total tracks: 8643
# reccommended len (finally 500) 8643
# relevent tracks size: 76
# sampled relevent tracks 20
# pid        : 10178
# rec. tracks: 500
# rel. tracks: 76
# click      : 6.2
# r_precision: 0.17105263157894737
# ndcg       : 0.04109686588408781
# Total similar playlists 100
# total tracks: 1734
# reccommended len (finally 500) 1734
# relevent tracks size: 73
# sampled relevent tracks 20
# pid        : 10179
# rec. tracks: 500
# rel. tracks: 73
# click      : 3.2
# r_precision: 0.3287671232876712
# ndcg       : 0.2591567687133617
# Total similar playlists 100
# total tracks: 1628
# reccommended len (finally 500) 1628
# relevent tracks size: 87
# sampled relevent tracks 20
# pid        : 10180
# rec. tracks: 500
# rel. tracks: 87
# click      : 0.0
# r_precision: 0.2413793103448276
# ndcg       : 0.13625361840049421
# Total similar playlists 100
# total tracks: 6925
# reccommended len (finally 500) 6925
# relevent tracks size: 49
# sampled relevent tracks 20
# pid        : 10181
# rec. tracks: 500
# rel. tracks: 49
# click      : 0.0
# r_precision: 0.02040816326530612
# ndcg       : 0.06025121717825992
# Total similar playlists 100
# total tracks: 1513
# reccommended len (finally 500) 1513
# relevent tracks size: 146
# sampled relevent tracks 20
# pid        : 10182
# rec. tracks: 500
# rel. tracks: 146
# click      : 0.0
# r_precision: 0.3287671232876712
# ndcg       : 0.3009487371327269
# Total similar playlists 100
# total tracks: 8676
# reccommended len (finally 500) 8676
# relevent tracks size: 34
# sampled relevent tracks 20
# pid        : 10183
# rec. tracks: 500
# rel. tracks: 34
# click      : 1.9
# r_precision: 0.14705882352941177
# ndcg       : 0.06351665172416254
# Total similar playlists 100
# total tracks: 1762
# reccommended len (finally 500) 1762
# relevent tracks size: 51
# sampled relevent tracks 20
# pid        : 10184
# rec. tracks: 500
# rel. tracks: 51
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 2415
# reccommended len (finally 500) 2415
# relevent tracks size: 62
# sampled relevent tracks 20
# pid        : 10185
# rec. tracks: 500
# rel. tracks: 62
# click      : 0.3
# r_precision: 0.3225806451612903
# ndcg       : 0.09963565636872075
# Total similar playlists 100
# total tracks: 5832
# reccommended len (finally 500) 5832
# relevent tracks size: 42
# sampled relevent tracks 20
# pid        : 10186
# rec. tracks: 500
# rel. tracks: 42
# click      : 3.3
# r_precision: 0.09523809523809523
# ndcg       : 0.014194489312516198
# Total similar playlists 100
# total tracks: 2507
# reccommended len (finally 500) 2507
# relevent tracks size: 108
# sampled relevent tracks 20
# pid        : 10187
# rec. tracks: 500
# rel. tracks: 108
# click      : 2.2
# r_precision: 0.09259259259259259
# ndcg       : 0.027820570727657697
# Total similar playlists 100
# total tracks: 1430
# reccommended len (finally 500) 1430
# relevent tracks size: 198
# sampled relevent tracks 20
# pid        : 10188
# rec. tracks: 500
# rel. tracks: 198
# click      : 51
# r_precision: 0.0
# ndcg       : 0.0
# Total similar playlists 100
# total tracks: 1688
# reccommended len (finally 500) 1688
# relevent tracks size: 59
# sampled relevent tracks 20
# pid        : 10189
# rec. tracks: 500
# rel. tracks: 59
# click      : 1.1
# r_precision: 0.03389830508474576
# ndcg       : 0.017827237779726147
# Total similar playlists 100
# total tracks: 1555
# reccommended len (finally 500) 1555
# relevent tracks size: 18
# sampled relevent tracks 18
# pid        : 10190
# rec. tracks: 500
# rel. tracks: 18
# click      : 3.1
# r_precision: 0.16666666666666666
# ndcg       : 0.008053015906439812
# Total similar playlists 100
# total tracks: 6017
# reccommended len (finally 500) 6017
# relevent tracks size: 41
# sampled relevent tracks 20
# pid        : 10191
# rec. tracks: 500
# rel. tracks: 41
# click      : 0.0
# r_precision: 0.4146341463414634
# ndcg       : 0.1727767195833527
# Total similar playlists 100
# total tracks: 1613
# reccommended len (finally 500) 1613
# relevent tracks size: 68
# sampled relevent tracks 20
# pid        : 10192
# rec. tracks: 500
# rel. tracks: 68
# click      : 1.5
# r_precision: 0.5882352941176471
# ndcg       : 0.4628160089476946
# Total similar playlists 100
# total tracks: 1656
# reccommended len (finally 500) 1656
# relevent tracks size: 185
# sampled relevent tracks 20
# pid        : 10193
# rec. tracks: 500
# rel. tracks: 185
# click      : 0.1
# r_precision: 0.13513513513513514
# ndcg       : 0.12378914649728864
# Total similar playlists 100
# total tracks: 5382
# reccommended len (finally 500) 5382
# relevent tracks size: 136
# sampled relevent tracks 20
# pid        : 10194
# rec. tracks: 500
# rel. tracks: 136
# click      : 1.8
# r_precision: 0.11764705882352941
# ndcg       : 0.06046488273878607
# Total similar playlists 100
# total tracks: 2135
# reccommended len (finally 500) 2135
# relevent tracks size: 73
# sampled relevent tracks 20
# pid        : 10195
# rec. tracks: 500
# rel. tracks: 73
# click      : 1.9
# r_precision: 0.2602739726027397
# ndcg       : 0.3279219186139175
# Total similar playlists 100
# total tracks: 3603
# reccommended len (finally 500) 3603
# relevent tracks size: 84
# sampled relevent tracks 20
# pid        : 10196
# rec. tracks: 500
# rel. tracks: 84
# click      : 0.0
# r_precision: 0.5714285714285714
# ndcg       : 0.28653142841596535
# Total similar playlists 100
# total tracks: 6915
# reccommended len (finally 500) 6915
# relevent tracks size: 53
# sampled relevent tracks 20
# pid        : 10197
# rec. tracks: 500
# rel. tracks: 53
# click      : 2.5
# r_precision: 0.07547169811320754
# ndcg       : 0.03293918556459541
# Total similar playlists 100
# total tracks: 2177
# reccommended len (finally 500) 2177
# relevent tracks size: 59
# sampled relevent tracks 20
# pid        : 10198
# rec. tracks: 500
# rel. tracks: 59
# click      : 16.1
# r_precision: 0.03389830508474576
# ndcg       : 0.003485418006368606
# Total similar playlists 100
# total tracks: 2784
# reccommended len (finally 500) 2784
# relevent tracks size: 29
# sampled relevent tracks 20
# pid        : 10199
# rec. tracks: 500
# rel. tracks: 29
# click      : 1.2
# r_precision: 0.3793103448275862
# ndcg       : 0.037264461467478215
# avg Clicks   : 9.066000000000006
# avg Precision: 0.18723535806330324
# avg nDCG     : 0.09486413948760446
# (9.066000000000006, 0.18723535806330324)
